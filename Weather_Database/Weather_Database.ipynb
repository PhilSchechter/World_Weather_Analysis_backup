# %%
# dependencies
import pandas as pd
import numpy as np
import random
import requests
import time
from citipy import citipy
from config import weather_api_key
from datetime import datetime

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create random latitude/longitude combinations
lats = np.random.uniform(low=-90.0, high=90.0, size=2000)
lngs = np.random.uniform(low=-180.0, high=180.0, size=2000)
lat_lng=zip(lats,lngs)
# turn coordinates into a list of pairs
coordinates = list(lat_lng)

# %%
# create a list of cities near the random long/lat points
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 729

# %%
# create an empty list to hold the weather data
city_data = []
# Print beginning of the logging
print("Beginning Data Retrieval         ")
print("---------------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ---------------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
        
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | karratha
# Processing Record 2 of Set 1 | srednekolymsk
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | jahrom
# City not found. Skipping...
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | ucluelet
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | irece
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | nedjo
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | cayenne
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | kananga
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | krasnogorsk
# Processing Record 20 of Set 1 | tiznit
# Processing Record 21 of Set 1 | maceio
# Processing Record 22 of Set 1 | vila franca do campo
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | golakganj
# Processing Record 25 of Set 1 | andenes
# Processing Record 26 of Set 1 | mon
# Processing Record 27 of Set 1 | xinqing
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | coihaique
# Processing Record 30 of Set 1 | haines junction
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | bambous virieux
# Processing Record 34 of Set 1 | rio gallegos
# Processing Record 35 of Set 1 | talnakh
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | mayo
# Processing Record 39 of Set 1 | bilma
# Processing Record 40 of Set 1 | pangody
# Processing Record 41 of Set 1 | sisimiut
# Processing Record 42 of Set 1 | chikwawa
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | huamachuco
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | acarau
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | praia
# Processing Record 50 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 2 | hervey bay
# Processing Record 2 of Set 2 | jieshi
# Processing Record 3 of Set 2 | prenzlau
# Processing Record 4 of Set 2 | tadine
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | flinders
# Processing Record 8 of Set 2 | dingle
# Processing Record 9 of Set 2 | tulagi
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | morant bay
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | nadym
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | te anau
# Processing Record 20 of Set 2 | himora
# City not found. Skipping...
# Processing Record 21 of Set 2 | camabatela
# Processing Record 22 of Set 2 | daru
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | kahului
# Processing Record 25 of Set 2 | marawi
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | asau
# Processing Record 29 of Set 2 | singkang
# Processing Record 30 of Set 2 | mpika
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | tuatapere
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | faanui
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | grand gaube
# Processing Record 41 of Set 2 | nuuk
# Processing Record 42 of Set 2 | mumford
# Processing Record 43 of Set 2 | appleton
# Processing Record 44 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 2 | coquimbo
# Processing Record 46 of Set 2 | lompoc
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | taltal
# Processing Record 49 of Set 2 | ponta delgada
# Processing Record 50 of Set 2 | ilulissat
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | guiglo
# Processing Record 3 of Set 3 | genhe
# Processing Record 4 of Set 3 | san cristobal
# Processing Record 5 of Set 3 | aksarka
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | kaitangata
# Processing Record 8 of Set 3 | vilyuysk
# Processing Record 9 of Set 3 | ranong
# Processing Record 10 of Set 3 | hovd
# Processing Record 11 of Set 3 | anahuac
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | port elizabeth
# Processing Record 14 of Set 3 | fukue
# Processing Record 15 of Set 3 | chitipa
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | kendari
# Processing Record 18 of Set 3 | opuwo
# Processing Record 19 of Set 3 | mae hong son
# Processing Record 20 of Set 3 | cape town
# Processing Record 21 of Set 3 | padang
# Processing Record 22 of Set 3 | nantucket
# Processing Record 23 of Set 3 | figline valdarno
# Processing Record 24 of Set 3 | port blair
# Processing Record 25 of Set 3 | nalut
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | luderitz
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | lagos
# Processing Record 30 of Set 3 | svetlogorsk
# Processing Record 31 of Set 3 | severo-kurilsk
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | palauig
# Processing Record 34 of Set 3 | khani
# Processing Record 35 of Set 3 | vaini
# Processing Record 36 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 3 | san policarpo
# Processing Record 38 of Set 3 | kaohsiung
# Processing Record 39 of Set 3 | matamoros
# Processing Record 40 of Set 3 | pokrovsk
# Processing Record 41 of Set 3 | bahia honda
# Processing Record 42 of Set 3 | brae
# Processing Record 43 of Set 3 | vao
# Processing Record 44 of Set 3 | sitka
# Processing Record 45 of Set 3 | portland
# Processing Record 46 of Set 3 | sayat
# Processing Record 47 of Set 3 | seoul
# Processing Record 48 of Set 3 | abu kamal
# Processing Record 49 of Set 3 | jiuquan
# Processing Record 50 of Set 3 | dourbali
# Processing Record 1 of Set 4 | bima
# Processing Record 2 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 4 | mitu
# Processing Record 4 of Set 4 | turukhansk
# Processing Record 5 of Set 4 | pokosnoye
# Processing Record 6 of Set 4 | tessalit
# Processing Record 7 of Set 4 | lavrentiya
# Processing Record 8 of Set 4 | mount gambier
# Processing Record 9 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 4 | kaka
# Processing Record 11 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 4 | margate
# Processing Record 14 of Set 4 | hornepayne
# Processing Record 15 of Set 4 | buluang
# Processing Record 16 of Set 4 | bairiki
# Processing Record 17 of Set 4 | bethel
# Processing Record 18 of Set 4 | bubaque
# Processing Record 19 of Set 4 | vanavara
# Processing Record 20 of Set 4 | vila velha
# Processing Record 21 of Set 4 | sulphur springs
# Processing Record 22 of Set 4 | nanortalik
# Processing Record 23 of Set 4 | palu
# Processing Record 24 of Set 4 | bumba
# Processing Record 25 of Set 4 | airai
# Processing Record 26 of Set 4 | yarada
# Processing Record 27 of Set 4 | goderich
# Processing Record 28 of Set 4 | belmonte
# Processing Record 29 of Set 4 | parabel
# Processing Record 30 of Set 4 | hobyo
# Processing Record 31 of Set 4 | fairbanks
# Processing Record 32 of Set 4 | laukaa
# Processing Record 33 of Set 4 | nanakuli
# Processing Record 34 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 35 of Set 4 | ekhabi
# Processing Record 36 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 4 | husavik
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | nikolskoye
# Processing Record 40 of Set 4 | tocache
# Processing Record 41 of Set 4 | biak
# Processing Record 42 of Set 4 | mackay
# Processing Record 43 of Set 4 | seymchan
# Processing Record 44 of Set 4 | upata
# Processing Record 45 of Set 4 | svencionys
# Processing Record 46 of Set 4 | la jigua
# Processing Record 47 of Set 4 | moree
# Processing Record 48 of Set 4 | saint george
# Processing Record 49 of Set 4 | batemans bay
# Processing Record 50 of Set 4 | murashi
# Processing Record 1 of Set 5 | zabaykalsk
# Processing Record 2 of Set 5 | conakry
# Processing Record 3 of Set 5 | saint anthony
# Processing Record 4 of Set 5 | avanigadda
# Processing Record 5 of Set 5 | obihiro
# Processing Record 6 of Set 5 | liverpool
# Processing Record 7 of Set 5 | longyearbyen
# Processing Record 8 of Set 5 | college
# Processing Record 9 of Set 5 | ahipara
# Processing Record 10 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 5 | high rock
# Processing Record 12 of Set 5 | guerrero negro
# Processing Record 13 of Set 5 | taoudenni
# Processing Record 14 of Set 5 | hambantota
# Processing Record 15 of Set 5 | mahebourg
# Processing Record 16 of Set 5 | shiyan
# Processing Record 17 of Set 5 | tabou
# Processing Record 18 of Set 5 | grindavik
# Processing Record 19 of Set 5 | xunchang
# Processing Record 20 of Set 5 | hlukhiv
# Processing Record 21 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 5 | kulu
# Processing Record 23 of Set 5 | dandong
# Processing Record 24 of Set 5 | salalah
# Processing Record 25 of Set 5 | bend
# Processing Record 26 of Set 5 | sawakin
# Processing Record 27 of Set 5 | sampit
# Processing Record 28 of Set 5 | uthal
# Processing Record 29 of Set 5 | boa vista
# Processing Record 30 of Set 5 | northam
# Processing Record 31 of Set 5 | sabha
# Processing Record 32 of Set 5 | esperance
# Processing Record 33 of Set 5 | waipawa
# Processing Record 34 of Set 5 | tarakan
# Processing Record 35 of Set 5 | guiratinga
# Processing Record 36 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 5 | paamiut
# Processing Record 38 of Set 5 | nokha
# Processing Record 39 of Set 5 | ise
# Processing Record 40 of Set 5 | saldanha
# Processing Record 41 of Set 5 | harrisonburg
# Processing Record 42 of Set 5 | baykit
# Processing Record 43 of Set 5 | puqi
# Processing Record 44 of Set 5 | hofn
# Processing Record 45 of Set 5 | mahenge
# Processing Record 46 of Set 5 | darab
# Processing Record 47 of Set 5 | marsh harbour
# Processing Record 48 of Set 5 | boddam
# Processing Record 49 of Set 5 | barra patuca
# Processing Record 50 of Set 5 | quatre cocos
# Processing Record 1 of Set 6 | fortuna
# Processing Record 2 of Set 6 | san patricio
# Processing Record 3 of Set 6 | nome
# Processing Record 4 of Set 6 | taunton
# Processing Record 5 of Set 6 | sistranda
# Processing Record 6 of Set 6 | porto santo
# Processing Record 7 of Set 6 | bila tserkva
# Processing Record 8 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | zhanakorgan
# Processing Record 10 of Set 6 | tura
# Processing Record 11 of Set 6 | gigmoto
# Processing Record 12 of Set 6 | arraial do cabo
# Processing Record 13 of Set 6 | bac lieu
# Processing Record 14 of Set 6 | comodoro rivadavia
# Processing Record 15 of Set 6 | rundu
# Processing Record 16 of Set 6 | manokwari
# Processing Record 17 of Set 6 | weligama
# Processing Record 18 of Set 6 | ponta do sol
# Processing Record 19 of Set 6 | sao filipe
# Processing Record 20 of Set 6 | vardo
# Processing Record 21 of Set 6 | veraval
# Processing Record 22 of Set 6 | zarubino
# Processing Record 23 of Set 6 | ashland
# Processing Record 24 of Set 6 | kodinsk
# Processing Record 25 of Set 6 | alice springs
# Processing Record 26 of Set 6 | pucallpa
# Processing Record 27 of Set 6 | lorengau
# Processing Record 28 of Set 6 | soanierana ivongo
# Processing Record 29 of Set 6 | henties bay
# Processing Record 30 of Set 6 | beranang
# Processing Record 31 of Set 6 | chocope
# Processing Record 32 of Set 6 | saint-louis
# Processing Record 33 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 6 | cabo san lucas
# Processing Record 35 of Set 6 | honningsvag
# Processing Record 36 of Set 6 | anito
# Processing Record 37 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 6 | necochea
# Processing Record 39 of Set 6 | ferme-neuve
# Processing Record 40 of Set 6 | trairi
# Processing Record 41 of Set 6 | burica
# City not found. Skipping...
# Processing Record 42 of Set 6 | cabedelo
# Processing Record 43 of Set 6 | shakawe
# Processing Record 44 of Set 6 | kavieng
# Processing Record 45 of Set 6 | svetlyy
# Processing Record 46 of Set 6 | namibe
# Processing Record 47 of Set 6 | sechura
# Processing Record 48 of Set 6 | vanimo
# Processing Record 49 of Set 6 | khandyga
# Processing Record 50 of Set 6 | dunedin
# Processing Record 1 of Set 7 | dakar
# Processing Record 2 of Set 7 | saskylakh
# Processing Record 3 of Set 7 | auki
# Processing Record 4 of Set 7 | san juan
# Processing Record 5 of Set 7 | broome
# Processing Record 6 of Set 7 | catamarca
# Processing Record 7 of Set 7 | lebu
# Processing Record 8 of Set 7 | saint-philippe
# Processing Record 9 of Set 7 | alyangula
# Processing Record 10 of Set 7 | yumen
# Processing Record 11 of Set 7 | lagoa
# Processing Record 12 of Set 7 | loandjili
# Processing Record 13 of Set 7 | westport
# Processing Record 14 of Set 7 | thornbury
# Processing Record 15 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 7 | santa barbara
# Processing Record 17 of Set 7 | constantine
# Processing Record 18 of Set 7 | we
# City not found. Skipping...
# Processing Record 19 of Set 7 | codrington
# Processing Record 20 of Set 7 | angoram
# Processing Record 21 of Set 7 | sivas
# Processing Record 22 of Set 7 | muli
# Processing Record 23 of Set 7 | kitami
# Processing Record 24 of Set 7 | tual
# Processing Record 25 of Set 7 | banjar
# Processing Record 26 of Set 7 | kirensk
# Processing Record 27 of Set 7 | salisbury
# Processing Record 28 of Set 7 | wanaka
# Processing Record 29 of Set 7 | constancia
# Processing Record 30 of Set 7 | yar-sale
# Processing Record 31 of Set 7 | buala
# Processing Record 32 of Set 7 | leno
# Processing Record 33 of Set 7 | ilinskiy
# Processing Record 34 of Set 7 | freeport
# Processing Record 35 of Set 7 | suriapet
# Processing Record 36 of Set 7 | camrose
# Processing Record 37 of Set 7 | cozumel
# Processing Record 38 of Set 7 | kruisfontein
# Processing Record 39 of Set 7 | verkhnyaya inta
# Processing Record 40 of Set 7 | nouadhibou
# Processing Record 41 of Set 7 | kaeo
# Processing Record 42 of Set 7 | naze
# Processing Record 43 of Set 7 | georgetown
# Processing Record 44 of Set 7 | komsomolskiy
# Processing Record 45 of Set 7 | cap malheureux
# Processing Record 46 of Set 7 | pevek
# Processing Record 47 of Set 7 | katangli
# Processing Record 48 of Set 7 | ayolas
# Processing Record 49 of Set 7 | ambilobe
# Processing Record 50 of Set 7 | tirano
# Processing Record 1 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 8 | kedrovyy
# Processing Record 3 of Set 8 | kambove
# Processing Record 4 of Set 8 | qiongshan
# Processing Record 5 of Set 8 | galle
# Processing Record 6 of Set 8 | beyneu
# Processing Record 7 of Set 8 | kadaya
# Processing Record 8 of Set 8 | nizhniy tsasuchey
# Processing Record 9 of Set 8 | bereda
# Processing Record 10 of Set 8 | klaksvik
# Processing Record 11 of Set 8 | los banos
# Processing Record 12 of Set 8 | rafaela
# Processing Record 13 of Set 8 | oussouye
# Processing Record 14 of Set 8 | shenjiamen
# Processing Record 15 of Set 8 | huarmey
# Processing Record 16 of Set 8 | okha
# Processing Record 17 of Set 8 | kalmunai
# Processing Record 18 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 8 | labuhan
# Processing Record 20 of Set 8 | bathsheba
# Processing Record 21 of Set 8 | koulamoutou
# Processing Record 22 of Set 8 | tutoia
# Processing Record 23 of Set 8 | pedasi
# Processing Record 24 of Set 8 | balkanabat
# Processing Record 25 of Set 8 | tsentralnyy
# City not found. Skipping...
# Processing Record 26 of Set 8 | kyzyl-suu
# Processing Record 27 of Set 8 | port augusta
# Processing Record 28 of Set 8 | debre tabor
# Processing Record 29 of Set 8 | san miguelito
# Processing Record 30 of Set 8 | omsukchan
# Processing Record 31 of Set 8 | caravelas
# Processing Record 32 of Set 8 | ariyalur
# Processing Record 33 of Set 8 | san vicente
# Processing Record 34 of Set 8 | mani
# Processing Record 35 of Set 8 | sikasso
# Processing Record 36 of Set 8 | yulara
# Processing Record 37 of Set 8 | scarborough
# Processing Record 38 of Set 8 | honiara
# Processing Record 39 of Set 8 | filingue
# Processing Record 40 of Set 8 | naron
# Processing Record 41 of Set 8 | sungaipenuh
# Processing Record 42 of Set 8 | port lincoln
# Processing Record 43 of Set 8 | kailua
# Processing Record 44 of Set 8 | ancud
# Processing Record 45 of Set 8 | nizwa
# Processing Record 46 of Set 8 | kudat
# Processing Record 47 of Set 8 | kirakira
# Processing Record 48 of Set 8 | diego de almagro
# Processing Record 49 of Set 8 | bati
# Processing Record 50 of Set 8 | san felipe
# Processing Record 1 of Set 9 | nishihara
# Processing Record 2 of Set 9 | katsuura
# Processing Record 3 of Set 9 | shaki
# Processing Record 4 of Set 9 | kommunarka
# Processing Record 5 of Set 9 | tabukiniberu
# City not found. Skipping...
# Processing Record 6 of Set 9 | byron bay
# Processing Record 7 of Set 9 | centralia
# Processing Record 8 of Set 9 | constitucion
# Processing Record 9 of Set 9 | karasjok
# Processing Record 10 of Set 9 | sorland
# Processing Record 11 of Set 9 | kapuskasing
# Processing Record 12 of Set 9 | ciudad bolivar
# Processing Record 13 of Set 9 | beringovskiy
# Processing Record 14 of Set 9 | yeppoon
# Processing Record 15 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 16 of Set 9 | batticaloa
# Processing Record 17 of Set 9 | sorong
# Processing Record 18 of Set 9 | kibaya
# Processing Record 19 of Set 9 | jizan
# Processing Record 20 of Set 9 | lingao
# Processing Record 21 of Set 9 | derzhavinsk
# Processing Record 22 of Set 9 | kanniyakumari
# Processing Record 23 of Set 9 | oudtshoorn
# Processing Record 24 of Set 9 | dana point
# Processing Record 25 of Set 9 | tulsipur
# Processing Record 26 of Set 9 | ondangwa
# Processing Record 27 of Set 9 | matagami
# Processing Record 28 of Set 9 | barroualie
# City not found. Skipping...
# Processing Record 29 of Set 9 | truro
# Processing Record 30 of Set 9 | sibu
# Processing Record 31 of Set 9 | ikom
# Processing Record 32 of Set 9 | norsup
# Processing Record 33 of Set 9 | qaqortoq
# Processing Record 34 of Set 9 | alta floresta
# Processing Record 35 of Set 9 | sohagpur
# Processing Record 36 of Set 9 | igarka
# Processing Record 37 of Set 9 | nyagan
# Processing Record 38 of Set 9 | ruteng
# Processing Record 39 of Set 9 | batagay
# Processing Record 40 of Set 9 | arlit
# Processing Record 41 of Set 9 | faya
# Processing Record 42 of Set 9 | sao joao da barra
# Processing Record 43 of Set 9 | sept-iles
# Processing Record 44 of Set 9 | bhavani
# Processing Record 45 of Set 9 | biloela
# Processing Record 46 of Set 9 | humberto de campos
# Processing Record 47 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 9 | ndele
# Processing Record 49 of Set 9 | salinopolis
# Processing Record 50 of Set 9 | pisco
# Processing Record 1 of Set 10 | torres
# Processing Record 2 of Set 10 | kirkuk
# Processing Record 3 of Set 10 | luena
# Processing Record 4 of Set 10 | luganville
# Processing Record 5 of Set 10 | muros
# Processing Record 6 of Set 10 | killybegs
# Processing Record 7 of Set 10 | kiama
# Processing Record 8 of Set 10 | indi
# Processing Record 9 of Set 10 | surgut
# Processing Record 10 of Set 10 | shatrovo
# Processing Record 11 of Set 10 | staryy nadym
# Processing Record 12 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 10 | urumqi
# Processing Record 14 of Set 10 | wuwei
# Processing Record 15 of Set 10 | masumbwe
# Processing Record 16 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 10 | aklavik
# Processing Record 18 of Set 10 | manta
# Processing Record 19 of Set 10 | kattivakkam
# Processing Record 20 of Set 10 | santa catarina de tepehuanes
# Processing Record 21 of Set 10 | zhigansk
# Processing Record 22 of Set 10 | jacmel
# Processing Record 23 of Set 10 | sungairaya
# Processing Record 24 of Set 10 | port hedland
# Processing Record 25 of Set 10 | barcelona
# Processing Record 26 of Set 10 | natal
# Processing Record 27 of Set 10 | vestmanna
# Processing Record 28 of Set 10 | ejido
# Processing Record 29 of Set 10 | whitehorse
# Processing Record 30 of Set 10 | yanai
# Processing Record 31 of Set 10 | abeche
# Processing Record 32 of Set 10 | porto novo
# Processing Record 33 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 10 | kampot
# Processing Record 35 of Set 10 | high level
# Processing Record 36 of Set 10 | rawson
# Processing Record 37 of Set 10 | yerbogachen
# Processing Record 38 of Set 10 | laramie
# Processing Record 39 of Set 10 | zamora
# Processing Record 40 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 10 | berlevag
# Processing Record 42 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 43 of Set 10 | touros
# Processing Record 44 of Set 10 | bernal
# Processing Record 45 of Set 10 | bilibino
# Processing Record 46 of Set 10 | punta alta
# Processing Record 47 of Set 10 | kununurra
# Processing Record 48 of Set 10 | nuevo progreso
# Processing Record 49 of Set 10 | geraldton
# Processing Record 50 of Set 10 | qianan
# Processing Record 1 of Set 11 | el badari
# City not found. Skipping...
# Processing Record 2 of Set 11 | juneau
# Processing Record 3 of Set 11 | cotofanesti
# Processing Record 4 of Set 11 | santiago
# Processing Record 5 of Set 11 | svetlaya
# Processing Record 6 of Set 11 | sao sebastiao
# Processing Record 7 of Set 11 | manicore
# Processing Record 8 of Set 11 | general roca
# Processing Record 9 of Set 11 | loharu
# Processing Record 10 of Set 11 | aripuana
# Processing Record 11 of Set 11 | hasaki
# Processing Record 12 of Set 11 | kansk
# Processing Record 13 of Set 11 | setermoen
# Processing Record 14 of Set 11 | ciudad guayana
# Processing Record 15 of Set 11 | manadhoo
# Processing Record 16 of Set 11 | batouri
# Processing Record 17 of Set 11 | mirnyy
# Processing Record 18 of Set 11 | laguna
# Processing Record 19 of Set 11 | quesnel
# Processing Record 20 of Set 11 | seaforth
# Processing Record 21 of Set 11 | nikolayevka
# Processing Record 22 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 23 of Set 11 | ta khmau
# Processing Record 24 of Set 11 | chokurdakh
# Processing Record 25 of Set 11 | mokrousovo
# Processing Record 26 of Set 11 | changji
# Processing Record 27 of Set 11 | coruripe
# Processing Record 28 of Set 11 | bealanana
# Processing Record 29 of Set 11 | santiago del estero
# Processing Record 30 of Set 11 | anadyr
# Processing Record 31 of Set 11 | staroshcherbinovskaya
# Processing Record 32 of Set 11 | coolum beach
# Processing Record 33 of Set 11 | alofi
# Processing Record 34 of Set 11 | tilichiki
# Processing Record 35 of Set 11 | saint-augustin
# Processing Record 36 of Set 11 | de-kastri
# Processing Record 37 of Set 11 | zanzibar
# Processing Record 38 of Set 11 | breyten
# Processing Record 39 of Set 11 | nabire
# Processing Record 40 of Set 11 | aykhal
# Processing Record 41 of Set 11 | hays
# Processing Record 42 of Set 11 | burnie
# Processing Record 43 of Set 11 | subaytilah
# City not found. Skipping...
# Processing Record 44 of Set 11 | jalu
# Processing Record 45 of Set 11 | seminole
# Processing Record 46 of Set 11 | lasa
# Processing Record 47 of Set 11 | ulladulla
# Processing Record 48 of Set 11 | isangel
# Processing Record 49 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 11 | ust-nera
# Processing Record 1 of Set 12 | la ronge
# Processing Record 2 of Set 12 | dryden
# Processing Record 3 of Set 12 | walvis bay
# Processing Record 4 of Set 12 | sola
# Processing Record 5 of Set 12 | abhar
# Processing Record 6 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 12 | mandal
# Processing Record 8 of Set 12 | baiao
# Processing Record 9 of Set 12 | cap-chat
# Processing Record 10 of Set 12 | grand island
# Processing Record 11 of Set 12 | hunchun
# Processing Record 12 of Set 12 | nokaneng
# Processing Record 13 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 12 | manthani
# Processing Record 15 of Set 12 | port macquarie
# Processing Record 16 of Set 12 | price
# Processing Record 17 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 18 of Set 12 | gurkovo
# Processing Record 19 of Set 12 | anastacio
# Processing Record 20 of Set 12 | mandan
# Processing Record 21 of Set 12 | olinda
# Processing Record 22 of Set 12 | korla
# Processing Record 23 of Set 12 | gravdal
# Processing Record 24 of Set 12 | arosa
# Processing Record 25 of Set 12 | deputatskiy
# Processing Record 26 of Set 12 | marzuq
# Processing Record 27 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 12 | itoman
# Processing Record 29 of Set 12 | adre
# Processing Record 30 of Set 12 | along
# Processing Record 31 of Set 12 | dawlatabad
# Processing Record 32 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 33 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 12 | bengkulu
# Processing Record 35 of Set 12 | zhigalovo
# Processing Record 36 of Set 12 | beipiao
# Processing Record 37 of Set 12 | gainesville
# Processing Record 38 of Set 12 | dukat
# Processing Record 39 of Set 12 | ullapool
# Processing Record 40 of Set 12 | sao miguel do araguaia
# Processing Record 41 of Set 12 | yashkino
# Processing Record 42 of Set 12 | ascension
# Processing Record 43 of Set 12 | libreville
# Processing Record 44 of Set 12 | falaleu
# City not found. Skipping...
# Processing Record 45 of Set 12 | ostrovnoy
# Processing Record 46 of Set 12 | corowa
# Processing Record 47 of Set 12 | provideniya
# Processing Record 48 of Set 12 | ayan
# Processing Record 49 of Set 12 | taganak
# Processing Record 50 of Set 12 | puerto penasco
# Processing Record 1 of Set 13 | pozzallo
# Processing Record 2 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 13 | shablykino
# Processing Record 4 of Set 13 | ringwood
# Processing Record 5 of Set 13 | saint stephen
# Processing Record 6 of Set 13 | hamilton
# Processing Record 7 of Set 13 | bachaquero
# Processing Record 8 of Set 13 | jinji
# Processing Record 9 of Set 13 | lagunas
# Processing Record 10 of Set 13 | vernon
# Processing Record 11 of Set 13 | metu
# Processing Record 12 of Set 13 | san luis
# Processing Record 13 of Set 13 | ha giang
# Processing Record 14 of Set 13 | mpulungu
# Processing Record 15 of Set 13 | piribebuy
# Processing Record 16 of Set 13 | general pico
# Processing Record 17 of Set 13 | noumea
# Processing Record 18 of Set 13 | soata
# Processing Record 19 of Set 13 | misratah
# Processing Record 20 of Set 13 | fomboni
# Processing Record 21 of Set 13 | guiberoua
# Processing Record 22 of Set 13 | porto velho
# Processing Record 23 of Set 13 | maku
# Processing Record 24 of Set 13 | folsom
# Processing Record 25 of Set 13 | laguna de perlas
# Processing Record 26 of Set 13 | yabrud
# Processing Record 27 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 28 of Set 13 | erdenet
# Processing Record 29 of Set 13 | krasnoselkup
# Processing Record 30 of Set 13 | beaverlodge
# Processing Record 31 of Set 13 | la palma
# Processing Record 32 of Set 13 | langres
# Processing Record 33 of Set 13 | aranos
# Processing Record 34 of Set 13 | puerto del rosario
# Processing Record 35 of Set 13 | pallasovka
# Processing Record 36 of Set 13 | pacific grove
# Processing Record 37 of Set 13 | taikang
# Processing Record 38 of Set 13 | ayorou
# Processing Record 39 of Set 13 | santa cruz
# Processing Record 40 of Set 13 | malartic
# Processing Record 41 of Set 13 | saint-pierre
# Processing Record 42 of Set 13 | allapalli
# Processing Record 43 of Set 13 | turtas
# Processing Record 44 of Set 13 | huaidian
# Processing Record 45 of Set 13 | belaya gora
# Processing Record 46 of Set 13 | enshi
# Processing Record 47 of Set 13 | lamar
# Processing Record 48 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 13 | jiexiu
# Processing Record 50 of Set 13 | richard toll
# City not found. Skipping...
# Processing Record 1 of Set 14 | evensk
# Processing Record 2 of Set 14 | rokytne
# Processing Record 3 of Set 14 | salinas
# Processing Record 4 of Set 14 | aurad
# Processing Record 5 of Set 14 | dorado
# Processing Record 6 of Set 14 | loreto
# Processing Record 7 of Set 14 | liuli
# Processing Record 8 of Set 14 | kabalo
# Processing Record 9 of Set 14 | mildura
# Processing Record 10 of Set 14 | mooi river
# City not found. Skipping...
# Processing Record 11 of Set 14 | cabras
# Processing Record 12 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 14 | lubao
# Processing Record 14 of Set 14 | zhanaozen
# Processing Record 15 of Set 14 | rocha
# Processing Record 16 of Set 14 | usinsk
# Processing Record 17 of Set 14 | pampas
# Processing Record 18 of Set 14 | beisfjord
# Processing Record 19 of Set 14 | raga
# Processing Record 20 of Set 14 | bamban
# Processing Record 21 of Set 14 | brainerd
# Processing Record 22 of Set 14 | peleduy
# Processing Record 23 of Set 14 | hosakote
# Processing Record 24 of Set 14 | lhokseumawe
# Processing Record 25 of Set 14 | amga
# Processing Record 26 of Set 14 | havoysund
# Processing Record 27 of Set 14 | moba
# Processing Record 28 of Set 14 | ahmadpur east
# Processing Record 29 of Set 14 | suba
# Processing Record 30 of Set 14 | chinna salem
# Processing Record 31 of Set 14 | dalbandin
# Processing Record 32 of Set 14 | sur
# Processing Record 33 of Set 14 | tautira
# Processing Record 34 of Set 14 | yunyang
# Processing Record 35 of Set 14 | olafsvik
# Processing Record 36 of Set 14 | odder
# Processing Record 37 of Set 14 | kailasahar
# City not found. Skipping...
# Processing Record 38 of Set 14 | pedernales
# Processing Record 39 of Set 14 | capao da canoa
# Processing Record 40 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 41 of Set 14 | sao miguel
# Processing Record 42 of Set 14 | vytegra
# Processing Record 43 of Set 14 | kushima
# Processing Record 44 of Set 14 | san ignacio
# Processing Record 45 of Set 14 | adrar
# Processing Record 46 of Set 14 | colomi
# Processing Record 47 of Set 14 | archidona
# Processing Record 48 of Set 14 | severo-yeniseyskiy
# Processing Record 49 of Set 14 | kenai
# Processing Record 50 of Set 14 | kota bahru
# Processing Record 1 of Set 15 | kuala terengganu
# Processing Record 2 of Set 15 | port shepstone
# Processing Record 3 of Set 15 | guadalupe victoria
# Processing Record 4 of Set 15 | berberati
# Processing Record 5 of Set 15 | olutanga
# Processing Record 6 of Set 15 | baruun-urt
# Processing Record 7 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 15 | priekule
# Processing Record 9 of Set 15 | aden
# Processing Record 10 of Set 15 | tupanatinga
# Processing Record 11 of Set 15 | ust-kuyga
# Processing Record 12 of Set 15 | worland
# Processing Record 13 of Set 15 | magadan
# Processing Record 14 of Set 15 | vestmannaeyjar
# Processing Record 15 of Set 15 | merrill
# Processing Record 16 of Set 15 | aromashevo
# Processing Record 17 of Set 15 | wanxian
# Processing Record 18 of Set 15 | elliot
# Processing Record 19 of Set 15 | patu
# Processing Record 20 of Set 15 | pringsewu
# Processing Record 21 of Set 15 | delta del tigre
# Processing Record 22 of Set 15 | windsor
# Processing Record 23 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 15 | butterworth
# Processing Record 25 of Set 15 | rio de janeiro
# Processing Record 26 of Set 15 | batagay-alyta
# Processing Record 27 of Set 15 | basudebpur
# Processing Record 28 of Set 15 | pala
# Processing Record 29 of Set 15 | los llanos de aridane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv("WeatherPy_Database.csv")
